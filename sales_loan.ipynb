# %% [markdown]
# Hal pertama yang perlu dilakukan adalah me- <i>load</i> data loan data CSV dengan menggunakan module pandas. <br>
# Data kemudian ditampilkan dan diamati untuk masing-masing field-nya.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#load raw data
df_loan = pd.read_csv("loan_data_2007_2014.csv", low_memory=False)
df_loan = df_loan.drop("Unnamed: 0", axis=1)

# %%
df_loan.head(10)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term
# 0  1077501    1296599       5000         5000           4975.0   36 months  \
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
# 8  1071795    1306957       5600         5600           5600.0   60 months
# 9  1071570    1306721       5375         5375           5350.0   60 months
#
#    int_rate  installment grade sub_grade  ... total_bal_il il_util
# 0     10.65       162.87     B        B2  ...          NaN     NaN  \
# ...

# %%
df_loan_col = df_loan.columns
df_loan_col
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
# ...

# %% [markdown]
# Dapat dilihat ada banyak kolom yang kosong yang tentunya tidak dibutuhkan dan bisa dihilangkan. <br>
# Selain itu, kolom-kolom seperti grade, sub_grade merupakan kolom yang merupakan hasil dari perhitungan kolom lain, sehingga tidak untuk dimasukkan ke dalam model <br>
# Kolom grade ini akan menjadi kolom uji

# %%
df = df_loan.iloc[:, :9]
print("df")
df.head()
# Out:
# df
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term
# 0  1077501    1296599       5000         5000           4975.0   36 months  \
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade
# 0     10.65       162.87     B
# 1     15.27        59.83     C
# 2     15.96        84.33     C
# 3     13.49       339.31     C
# 4     12.69        67.79     B

# %% [markdown]
# Selanjutnya adalah menghilangkan kata 'months' pada term dan mengubah tipe datanya menjadi numerik agar lebih mudah dalam perhitungan.

# %%
df.dtypes
# Out:
# id                   int64
# member_id            int64
# loan_amnt            int64
# funded_amnt          int64
# funded_amnt_inv    float64
# term                object
# int_rate           float64
# installment        float64
# grade               object
# dtype: object

# %%
df['term'] = df['term'].str.replace('months','').str.strip().astype(int)
df_dum = pd.get_dummies(df)

# %%
from sklearn.model_selection import train_test_split
X = df.drop('grade',axis=1)
y = df['grade'].values
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size= 0.2, random_state=11)

# %%
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.model_selection import cross_val_score

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 lm = LinearRegression()
# ----> 2 lm.fit(X_train, y_train)
#
# File c:\Users\asus\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# ...
